# %%
from Scoring_model1 import model as model1
from Scoring_model2 import model as model2
import numpy as np
import pandas as pd

# %%
#instantiate models
clf1 = model1()
clf2 = model2()
model = None
filename = None

# %%
#build both models
clf1.build_model()
clf2.build_model()
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['index', 'limit_bal', 'age',
#                                                    'bill_statement_sep',
#                                                    'bill_statement_aug',
#                                                    'bill_statement_jul',
#                                                    'bill_statement_jun',
#                                                    'bill_statement_may',
#                                                    'bill_statement_apr',
# ...

# %%
#store the roc scores
clf1_rocScore = clf1.get_roc_score()
clf2_rocScore = clf2.get_roc_score()

# %%
print('ROC Score for model1: ', clf1_rocScore)
print('ROC Score for model2: ', clf2_rocScore)
# Out:
# ROC Score for model1:  0.6016633255771463
# ROC Score for model2:  0.5690012257560025

# %%
#get sample features to be predicted
features = {
    'index': 0, 'limit_bal': 0, 'sex': 'string', 'education': 'string', 'marriage': 'string', 'age': 0,
       'payment_status_sep': 'string', 'payment_status_aug': 'string', 'payment_status_jul': 'string',
       'payment_status_jun': 'string', 'payment_status_may': 'string', 'payment_status_apr': 'string',
       'bill_statement_sep': 0, 'bill_statement_aug': 0, 'bill_statement_jul': 0,
       'bill_statement_jun': 0, 'bill_statement_may': 0, 'bill_statement_apr': 0,
       'previous_payment_sep': 0, 'previous_payment_aug': 689, 'previous_payment_jul': 0,
       'previous_payment_jun': 0, 'previous_payment_may': 0, 'previous_payment_apr': 0}

# %%
#compare roc scores
model = None
if clf1_rocScore > clf2_rocScore:
    model = clf1
    filename = clf1.dump()
else:
    model = clf2
    filename = clf2.dump()

# %%
model.build_model()
model.load()
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['index', 'limit_bal', 'age',
#                                                    'bill_statement_sep',
#                                                    'bill_statement_aug',
#                                                    'bill_statement_jul',
#                                                    'bill_statement_jun',
#                                                    'bill_statement_may',
#                                                    'bill_statement_apr',
# ...

# %%
features = pd.DataFrame([features])

# %%
predictions = model.get_predictions(features)

# %%
predictions
# Out:
# array([1], dtype=int64)
